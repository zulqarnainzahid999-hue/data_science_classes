# %%
## class

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
name = 'pakistan'
print(type(name))
# Out:
# <class 'str'>

# %%
class car():
    make = 'Honda'
    model = 'Civic'
    year = 2020

# %%
car1 = car()

# %%
car1.make
# Out:
# 'Honda'

# %%
car1.model
# Out:
# 'Civic'

# %%
car1.year
# Out:
# 2020

# %%
car()

# %%
car2 = car()

# %%
car2.make
# Out:
# 'Honda'

# %%
car2.model
# Out:
# 'Civic'

# %%
car2.year
# Out:
# 2020

# %%
class car:
    def __init__(self, make, model, year):
        make = make
        model = model
        year = year

# %%
car1 = ('honda','civic', 2020)

# %%
car1.make
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 car1.make
#
# AttributeError: 'tuple' object has no attribute 'make'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

# %%
car1 = car('honda','civic', 2020)

# %%
car1.make
# Out:
# 'honda'

# %%
car1.model
# Out:
# 'civic'

# %%
car1.year
# Out:
# 2020

# %%
car2 = car('toyota', 'grande', 2020)

# %%
car2.make
# Out:
# 'toyota'

# %%
car2.model
# Out:
# 'grande'

# %%
print(car1.make)
print(car2.make)
# Out:
# honda
# toyota

# %%
class car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    def apply_accelator(self):
        print('accelator is applied')
    def apply_breaks(self):
        print('breaks are applied')

# %%
new_car = car('bmw', 'm5', 2024)

# %%
new_car.year
# Out:
# 2024

# %%
new_car.apply_accelator()
# Out:
# accelator is applied

# %%
new_car.apply_breaks()
# Out:
# breaks are applied

# %%
another_car = car('toyota', 'supra', 2019)

# %%
another_car.apply_breaks()
# Out:
# breaks are applied

# %%
another_car.apply_accelator()
# Out:
# accelator is applied

# %%
class restaurant():
    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
    def describe(self):
        print(f'{self.restaurant_name}...{self.cuisine_type}')
    def open(self):
        print(f'{self.restaurant_name} is open now')

# %%
R1 = restaurant('kababjees', 'fastfood')

# %%
R1.describe()
# Out:
# kababjees...fastfood

# %%
R1.open()
# Out:
# kababjees is open now

# %%
R1.restaurant_name
# Out:
# 'kababjees'

# %%
R1.cuisine_type
# Out:
# 'fastfood'

# %%
class user:
    def __init__(self, first_name, last_name):
        self.first_name = first_name
        self.last_name = last_name
        self.full_name = f"{first_name} {last_name}"
    def describe_user(self):
        print(f'first name is {self.first_name} and last name is {self.last_name}')
    def greet_user(self):
        print(f'hello {self.full_name} how are you doing')

# %%
user1 = user('Zulqarnain', 'Zahid')

# %%
user1.describe_user()
# Out:
# first name is Zulqarnain and last name is Zahid

# %%
user1.greet_user()
# Out:
# hello Zulqarnain Zahid how are you doing

# %%
user1.full_name
# Out:
# 'Zulqarnain Zahid'

# %%
class user:
    def __init__(self, name, gender, course, age, campus):
        self.name = name
        self.gender = gender
        self.course = course
        self.age = age
        self.campus = campus
    def describe_user(self):
        print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage {self.age}')
    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')

# %%
Zulqarnain = user('Zulqarnain Zahid', 'Male', 'Data Science', 16, 'SMIT')
Zain = user('zain', 'male', 'Data sciencs', '18', 'SNIT')
Ahmad = user('Ahmad', 'male', 'DAta Science', '15', 'SMIT')

# %%
Zulqarnain.describe_user()
# Out:
# user
# name: Zulqarnain Zahid
# gender: Male
# campus: SMIT
# course: Data Science
# age 16

# %%
Zulqarnain.greet_user()
# Out:
# hello Zulqarnain Zahid wellcome to our page

# %%
Zulqarnain.describe_user()
Zain.describe_user()
Ahmad.describe_user()
# Out:
# user
# name: Zulqarnain Zahid
# gender: Male
# campus: SMIT
# course: Data Science
# age 16
# user
# name: zain
# gender: male
# campus: SNIT
# course: Data sciencs
# age 18
# user
# name: Ahmad
# gender: male
# campus: SMIT
# course: DAta Science
# age 15

# %%
class user:
    def __init__(self, name, gender, course, age, campus = "SMIT"):
        self.name = name
        self.gender = gender
        self.course = course
        self.age = age
        self.campus = campus

    def describe_user(self):
        print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage {self.age}')
    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')

# %%
Zulqarnain = user('Zulqarnain Zahid', 'Male', 'Data Science', 16)
Zain = user('zain', 'male', 'Data sciencs', '18', campus= "JDC")
Ahmad = user('Ahmad', 'male', 'DAta Science', '15')

# %%
Zulqarnain.describe_user()
Zain.describe_user()
Ahmad.describe_user()
# Out:
# user
# name: Zulqarnain Zahid
# gender: Male
# campus: SMIT
# course: Data Science
# age 16
# user
# name: zain
# gender: male
# campus: JDC
# course: Data sciencs
# age 18
# user
# name: Ahmad
# gender: male
# campus: SMIT
# course: DAta Science
# age 15

# %%
class user:
    def __init__(self, name, gender, course, age):
        self.name = name
        self.gender = gender
        self.course = course
        self.age = age
        self.campus = "SMIT"

    def describe_user(self):
        print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage {self.age}')
    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')

# %%
Zulqarnain = user('Zulqarnain Zahid', 'Male', 'Data Science', 16)
Zain = user('zain', 'male', 'Data sciencs', '18')
Ahmad = user('Ahmad', 'male', 'DAta Science', '15')

# %%
Zulqarnain.describe_user()
Zain.describe_user()
Ahmad.describe_user()
# Out:
# user
# name: Zulqarnain Zahid
# gender: Male
# campus: SMIT
# course: Data Science
# age 16
# user
# name: zain
# gender: male
# campus: SMIT
# course: Data sciencs
# age 18
# user
# name: Ahmad
# gender: male
# campus: SMIT
# course: DAta Science
# age 15

# %%
class user:
    def __init__(self, name, gender, course, age):
        self.name = name
        self.gender = gender
        self.course = course
        self.age = age
        self.campus = "SMIT"

    def describe_user(self):
        print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage {self.age}')
    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')
    def set_attribute(self, new_campus):
        self.campus = new_campus

# %%
Zulqarnain = user('Zulqarnain Zahid', 'Male', 'Data Science', 16)
Zain = user('zain', 'male', 'Data sciencs', '18')
Ahmad = user('Ahmad', 'male', 'DAta Science', '15')

# %%
Ahmad.campus = 'JDC'

# %%
Ahmad.campus
# Out:
# 'JDC'

# %%
Zulqarnain.campus
# Out:
# 'SMIT'

# %%
class user:
    def __init__(self, name, gender, course, age):
        self.name = name
        self.gender = gender
        self.course = course
        self.age = age
        self.campus = "SMIT"

    def describe_user(self):
        print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage {self.age}')
    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')
    def set_attribute(self, attribute, value):
        setattr(self, attribute, value)

# %%
Zulqarnain = user('Zulqarnain Zahid', 'Male', 'Data Science', 16)
Zain = user('zain', 'male', 'Data sciencs', '18')
Ahmad = user('Ahmad', 'male', 'DAta Science', '15')

# %%
Zain.name
# Out:
# 'zain'

# %%
Zain.set_attribute('name', 'zain_ul_abideen')

# %%
Zain.name
# Out:
# 'zain_ul_abideen'

# %%
Zain.describe_user()
# Out:
# user
# name: zain_ul_abideen
# gender: male
# campus: SMIT
# course: Data sciencs
# age 18
