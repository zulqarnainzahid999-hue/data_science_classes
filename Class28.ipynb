# %%
class User:
    def __init__(self, first_name, last_name, gender, age, campus):
        self.first_name = first_name
        self.last_name = last_name
        self.gender = gender
        self.age = age
        self.__campus = campus

    def change_campus(self, new_campus):
        self.campus = new_campus

    def show_campus(self):
        return self.__campus
    
    def describe_user(self):
        print(f'user\nFirst Name: {self.first_name}\nLast Name: {self.last_name}\ngender: {self.gender}\ncampus: {self.campus}\nage: {self.age}')

    def greet_user(self):
        print(f'hello {self.first_name} wellcome to our page')

# %%
Zulqarnain = User('Zulqarnain', 'Zahid', 'Male', 16, 'SMIT')

# %%
Zulqarnain.campus
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 Zulqarnain.campus
#
# AttributeError: 'User' object has no attribute 'campus'

# %%
Zulqarnain.show_campus()
# Out:
# 'SMIT'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class User:
    def __init__(self, first_name, last_name, age, gender):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
        self.gender = gender
        self.campus = 'SMIT'
    def describe_User(self):
        print(f'User\nFirst Name: {self.first_name}\nLast Name: {self.last_name}\nAge: {self.age}\nGender: {self.gender}\nCampus: {self.campus}\n')

    def greet_User(self):
        print(f'wellcome {self.first_name} how are you doing')

    def set_attribute(self, attribute, value):
        setattr (self, attribute, value)

# %%
Zulqarnain = User('Zulqarnain', 'Zahid', 16, 'Male')

# %%
Zulqarnain.describe_User()
# Out:
# User
# First Name: Zulqarnain
# Last Name: Zahid
# Age: 16
# Gender: Male
# Campus: SMIT

# %%
Zulqarnain.set_attribute('first_name', 'Zain')

# %%
Zulqarnain.first_name
# Out:
# 'Zain'

# %%
class User:
    def __init__(self, first_name, last_name, gender, age):
        self.first_name = first_name
        self.last_name = last_name
        self.gender = gender
        self.age = age
        self.campus = 'SMIT'

    def describe_user(self):
        print(f"User's name is {self.first_name} {self.last_name}\nAge: {self.age}\nGender: {self.gender}\nCampus: {self.campus}")

    def greet_user(self):
        print(f'Hello {self.first_name}Welcome to our page')
        
    # No need to create this method, since we have built in method setattr

    # def set_attribute(self,attribute, value):
    #     # self.attribute = value
    #     setattr(self, attribute, value)

# %%
Zulqarnain = User('Zulqarnain', 'Zahid', 'Male', 16)

# %%
setattr(Zulqarnain, 'first_name', 'zulqarnain')

# %%
Zulqarnain.first_name
# Out:
# 'zulqarnain'

# %%
setattr(Zulqarnain, 'first_name', 'Zulqarnain')

# %%
Zulqarnain.first_name
# Out:
# 'Zulqarnain'

# %%
class restaurant:
    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
        self.number_served = 0

    def describe_restaurant(self):
        print(f'wellcome to {restaurant_name} what would you like to eat')

    def open_restaurant(self):
        print(f'{restaurant_name} is open today')

    def set_number_served(self, new_value):
        self.number_served = new_value

    def increment_number_served(self, new_value):
        self.number_served += new_value

    def increment_one(self):
        self.number_served += 1

    def set_zero(self):
        self.number_served = 0

# %%
Kababjees = restaurant('Kababjees fried chicken', 'Fast food')

# %%
Kababjees.number_served
# Out:
# 0

# %%
Kababjees.number_served = 7

# %%
Kababjees.number_served
# Out:
# 7

# %%
Kababjees.set_number_served(8)

# %%
Kababjees.number_served
# Out:
# 8

# %%
Kababjees.increment_number_served(4)

# %%
Kababjees.number_served
# Out:
# 12

# %%
Kababjees.increment_one()

# %%
Kababjees.number_served
# Out:
# 13

# %%
Kababjees.set_zero()

# %%
Kababjees.number_served
# Out:
# 0

# %%
class car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def apply_accelator(self):
         print('accelator is applied')
    def apply_brakes(self):
        print('brakes are applied')

# %%
car1 = car('BMW', 'M5', '2020')

# %%
car1.apply_accelator()
# Out:
# accelator is applied

# %%
class Electriccar:
    def __init__(self, make, model, year, battery):
        self.make = make
        self.model = model
        self.year = year
        self.battery = battery

    def apply_accelator(self):
         print('accelator is applied')

    def apply_brakes(self):
        print('brakes are applied')

    def recharge(self):
        print('battery is recharged')

# %%
E1 = Electriccar('tesla', 'cyber truck', '2025', 'osaka')

# %%
E1.recharge()
# Out:
# battery is recharged

# %%
class electriccar(car):
    def __init__(self, make , model, year, battery):
        super().__init__(make, model, year)

        self.battery = battery

    def recharge(self):
        print('battery is recharged')

# %%
E2 = electriccar('tesla', 'cyber truck', 2022, 'osaka')

# %%
E2.battery
# Out:
# 'osaka'

# %%
E2.make
# Out:
# 'tesla'

# %%
class restaurant:
    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
        number_served = 0

    def describe_restaurant(self):
        print(f'wellcome to {self.restaurant_name} how can we help you')

    def open_restaurant(self):
        print(f'hello {self.restaurant_name} is open now')

    def set_number_served(self, new_value):
        self.number_served = new_value

    def increment_number_served(self, new_value):
        self.number_served += new_value

    def increment_one(self, new_value):
        self.number_served += 1

    def reset_number_served(self):
        self.number_served = 0

# %%
class icecreamstand(restaurant):
    def __init__(self, restaurant_name, cuisine_type, flavours):
        super().__init__(restaurant_name, cuisine_type)

        self.flavours = flavours

    def display_flavours(self):
        print(f'these are the available flavours{' '.join( self.flavours)}')

# %%
sweet_creme = icecreamstand('sweet_cream', 'any', 'vanila, chocolate, mango')

# %%
sweet_creme.cuisine_type
# Out:
# 'any'

# %%
sweet_creme.flavours
# Out:
# 'vanila, chocolate, mango'

# %%
sweet_creme.display_flavours()
# Out:
# these are the available flavoursv a n i l a ,   c h o c o l a t e ,   m a n g o
