# %%
def is_anagram(original, test):
    test = sorted(test.lower())
    original = sorted(original.lower())

    return test == original

# %%
is_anagram('toffe', 'foefet')
# Out:
# False

# %%
is_anagram('toffe', 'effot')
# Out:
# True

# %%
def warn_the_sheep(queue):
    wolf_index = queue.index('wolf') - len(queue)
    if wolf_index == -1:
      print('go away wolf and stop eating my sheeps')
    else:
       print(f'oi sheep number{len(queue) - (queue.index(wolf) + 1)} ! you are about to eaten by a wolf')

# %%
def guess_number(num = 19):
    number = int(input('enter your mumber'))
    if number == num:
            print('congratulatins your answer is correct')
    elif number > num:
            print('your number is high')
    else:
            print('your number is low')

# %%
guess_number()
19
# Out:
# your number is high

# %% [markdown]
#  ATM Cash Withdrawal
#
#  Ek function banao jo amount input le aur check kare:
#
#  Balance se zyada ho → error
#
#  Amount 500 ke multiple me ho
#
#  Successful withdrawal per remaining balance show kary

# %%
def ATM_Cash_withdrawal(amount = 500):
    withdraw = int(input('enter amount you want to withdraw'))
    if withdraw <= amount:
          print(f'{withdraw} are withdrawed and your remaining cash is {amount - withdraw}')
    else:
           print(f'insuficient balance your available balance is {amount}')

# %%
ATM_Cash_withdrawal()
# Out:
# 400 are withdrawed and your remaining cash is 100
