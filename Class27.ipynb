# %%
class user:
    def __init__(self, name, gender, course, age, campus):
        self.name = name
        self.gender = gender
        self.course = course
        self.age = age
        self.campus = campus
    def describe_user(self):
        print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage: {self.age}')
    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')

# %%
Zulqarnain = user('Zulqarnain Zahid', 'Male', 'Data Science', 16, 'SMIT')
Zain = user('zain', 'male', 'Data sciencs', '18', 'SNIT')
Ahmad = user('Ahmad', 'male', 'DAta Science', '15', 'SMIT')

# %%
Zulqarnain.describe_user()
# Out:
# user
# name: Zulqarnain Zahid
# gender: Male
# campus: SMIT
# course: Data Science
# age: 16

# %%
Zain.describe_user()
# Out:
# user
# name: zain
# gender: male
# campus: SNIT
# course: Data sciencs
# age: 18

# %%
Zain.name = 'Zain ul abideen'

# %%
Zain.name
# Out:
# 'Zain ul abideen'

# %%
Zain.describe_user()
# Out:
# user
# name: Zain ul abideen
# gender: male
# campus: JDC
# course: Data sciencs
# age: 18

# %%
Zain.campus = 'JDC'

# %%
class user:
    def __init__(self, name, gender, course, age, campus):
        self.name = name
        self.gender = gender
        self.course = course
        self.age = age
        self.campus = campus

    def change_campus(self, new_campus):
        self.campus = new_campus 

    def show_campus(self):
        return self.campus      

    def describe_user(self):
        print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage: {self.age}')

    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')

# %%
Zulqarnain = user('Zulqarnain Zahid', 'Male', 'Data Science', 16, 'SMIT')
Zain = user('zain', 'male', 'Data sciencs', '18', 'SNIT')
Ahmad = user('Ahmad', 'male', 'DAta Science', '15', 'SMIT')

# %%
Zulqarnain.change_campus('JDC')

# %%
Zulqarnain.show_campus()
# Out:
# 'JDC'

# %%
class user:
    def __init__(self, name, gender, course, age, campus):
        self.name = name
        self.gender = gender
        self.course = course
        self.age = age
        self.campus = campus

    def change_detail(self, new_name='', new_gender='', new_course='', new_age=None, new_campus=''):
        if new_name:
            self.name = new_name
        if new_gender:
            self.gender = new_gender
        if new_course:
            self.course = new_course
        if new_age:
            self.age = new_age
        if new_campus:
            self.campus = new_campus

    def show_campus(self):
        return self.campus      

    def describe_user(self):
        print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage: {self.age}')

    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')

# %%
Zulqarnain = user('Zulqarnain Zahid', 'Male', 'Data Science', 16, 'SMIT')
Zain = user('zain', 'male', 'Data sciencs', '18', 'SNIT')
Ahmad = user('Ahmad', 'male', 'DAta Science', '15', 'SMIT')

# %%
Ahmad.change_detail('kashan')

# %%
Ahmad.__dict__
# Out:
# {'name': 'kashan',
#  'gender': 'male',
#  'course': 'DAta Science',
#  'age': '15',
#  'campus': 'SMIT'}

# %%
setattr(Ahmad, 'name', 'Ahmad Hassan')

# %%
Ahmad.name
# Out:
# 'Ahmad Hassan'

# %%
class user:
    def __init__(self, name, gender, course, age, campus):
        self.name = name
        self.gender = gender
        self.course = course
        self.age = age
        self.campus = campus
        self.counter = 1
        self.update_object_data()

    def update_object_data(self):
        data = self.__dict__
        with open ('testing1.txt', 'a+') as f:
            f.write(f'User{self.counter}: \n')
            for attr, value in data.items():
                self.counter += 1
                if '_' in attr:
                    attr = ' '.join(attr.split('_')).title()
                else:
                    attr = attr.title()
                f.write(f'{attr}: {value}\n')
            f.write('\n')

    def describe_user(self):
        print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage {self.age}')
        
    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')

# %%
Zulqarnain = user('Zulqarnain Zahid', 'Male', 'Data Science', 16, 'SMIT')

# %%
Zain = user('zain', 'male', 'Data sciencs', '18', 'SNIT')

# %%
Zulqarnain.__dict__
# Out:
# {'name': 'Zulqarnain Zahid',
#  'gender': 'Male',
#  'course': 'Data Science',
#  'age': 16,
#  'campus': 'SMIT',
#  'counter': 7}

# %%
class user:
    def __init__(self, first_name, last_name, gender, campus, age):
        self.first_name = first_name
        self.last_name = last_name
        self.gender = gender
        self.campus = campus
        self.age = age
        self.counter = 1
        self.update_user_data()
    def update_user_data(self):
        data = self.__dict__
        with open ('testing1.txt', 'a+') as f:
            f.write(f'User{self.counter}:\n')
            for attr, value in data.items():
                self.counter += 1
                if '_' in attr:
                    attr = ' '.join(attr.split('_')).title()
                else:
                    attr = attr.title()
                f.write(f'{attr}: {value}\n')
            f.write('\n')
    def describe_user(self):
            print(f'user\nname: {self.name}\ngender: {self.gender}\ncampus: {self.campus}\ncourse: {self.course}\nage {self.age}')

    def greet_user(self):
        print(f'hello {self.name} wellcome to our page')

# %%
Zulqarnain = user('Zulqarnain', 'Zahid', 'Male', 'SMIT', 16)

# %%
Zain = user('zain', 'male', 'Data sciencs', '18', 'SNIT')

# %%
class User:
    counter = 0   # ← yeh main fix hai

    def __init__(self, first_name, last_name, gender, campus, age):
        self.first_name = first_name
        self.last_name = last_name
        self.gender = gender
        self.campus = campus
        self.age = age

        User.counter += 1
        self.counter = User.counter

        self.update_user_data()

    def update_user_data(self):
        with open('testing1.txt', 'a+') as f:
            f.write(f'User {self.counter}\n')
            f.write(f'First Name : {self.first_name}\n')
            f.write(f'Last Name  : {self.last_name}\n')
            f.write(f'Gender     : {self.gender}\n')
            f.write(f'Campus     : {self.campus}\n')
            f.write(f'Age        : {self.age}\n\n')

# %%
u1 = User("Zulqarnain", "Zahid", "Male", "SMIT", 20)
u2 = User("Ali", "Khan", "Male", "SMIT", 22)
