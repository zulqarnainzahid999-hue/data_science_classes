# %%
area >= 300000
pop >= 2500000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 area >= 300000
#       2 pop >= 2500000
#
# NameError: name 'area' is not defined

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv("car_data.csv")
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# 1        40 kms    Diesel
# 2    22,000 kms    Petrol
# 3    28,000 kms    Petrol
# 4    36,000 kms    Diesel
# ..          ...       ...
# 887         NaN       NaN
# 888  27,000 kms    Diesel
# 889  40,000 kms    Diesel
# 890      Petrol       NaN
# 891      Petrol       NaN
#
# [892 rows x 6 columns]

# %%
df = pd.read_csv("car_data.csv")
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# 1        40 kms    Diesel
# 2    22,000 kms    Petrol
# 3    28,000 kms    Petrol
# 4    36,000 kms    Diesel
# ..          ...       ...
# 887         NaN       NaN
# 888  27,000 kms    Diesel
# 889  40,000 kms    Diesel
# 890      Petrol       NaN
# 891      Petrol       NaN
#
# [892 rows x 6 columns]

# %%
data  = pd.read_csv("car_data.csv")

# %%
data.shape
# Out:
# (892, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %% [markdown]
# # Data Cleaning
# - Missing Values
#
#        Drop
#      - Drop the records having missing data
#      - Drop the columns having missing data
#
#        Fill
#      - Fill the missing values
#           - Hard coded value
#           - Calculated Values
#           - Following or Preceding
# - Duplicate Records
# - Outlier

# %% [markdown]
# # Missing Values: isna() isnull()

# %%
data.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
30,000
# Out:
# (30, 0)

# %%
data['kms_driven'].unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
#        '33,333 kms', '33,600 kms', '5,600 kms', '7,500 kms', '26,000 kms',
#        '24,330 kms', '65,480 kms', '28,028 kms', '2,00,000 kms',
#        '99,000 kms', '2,800 kms', '21,000 kms', '11,000 kms',
#        '66,000 kms', '3,000 kms', '7,000 kms', '38,500 kms', '37,200 kms',
#        '43,200 kms', '24,800 kms', '45,872 kms', '40,000 kms',
#        '11,400 kms', '97,200 kms', '52,000 kms', '31,000 kms',
#        '1,75,430 kms', '37,000 kms', '65,000 kms', '3,350 kms',
#        '75,000 kms', '62,000 kms', '73,000 kms', '2,200 kms',
#        '54,870 kms', '34,580 kms', '97,000 kms', '60 kms', '80,200 kms',
#        '3,200 kms', '0,000 kms', '5,000 kms', '588 kms', '71,200 kms',
#        '1,75,400 kms', '9,300 kms', '56,758 kms', '10,000 kms',
#        '56,450 kms', '56,000 kms', '32,700 kms', '9,000 kms', '73 kms',
#        '1,60,000 kms', '84,000 kms', '58,559 kms', '57,000 kms',
#        '1,70,000 kms', '80,000 kms', '6,821 kms', '23,000 kms',
#        '34,000 kms', '1,800 kms', '4,00,000 kms', '48,000 kms',
#        '90,000 kms', '12,000 kms', '69,900 kms', '1,66,000 kms',
#        '122 kms', '0 kms', '24,000 kms', '36,469 kms', '7,800 kms',
#        '24,695 kms', '15,141 kms', '59,910 kms', '1,00,000 kms',
#        '4,500 kms', '1,29,000 kms', '300 kms', '1,31,000 kms',
#        '1,11,111 kms', '59,466 kms', '25,500 kms', '44,005 kms',
#        '2,110 kms', '43,222 kms', '1,00,200 kms', '65 kms',
#        '1,40,000 kms', '1,03,553 kms', '58,000 kms', '1,20,000 kms',
#        '49,800 kms', '100 kms', '81,876 kms', '6,020 kms', '55,700 kms',
#        '18,500 kms', '1,80,000 kms', '53,000 kms', '35,500 kms',
#        '22,134 kms', '1,000 kms', '8,500 kms', '87,000 kms', '6,000 kms',
#        '15,574 kms', '8,000 kms', '55,800 kms', '56,400 kms',
#        '72,160 kms', '11,500 kms', '1,33,000 kms', '2,000 kms',
#        '88,000 kms', '65,422 kms', '1,17,000 kms', '1,50,000 kms',
#        '10,750 kms', '6,800 kms', '5 kms', '9,800 kms', '57,923 kms',
#        '30,201 kms', '6,200 kms', '37,518 kms', '24,652 kms', '383 kms',
#        '95,000 kms', '3,528 kms', '52,500 kms', '47,900 kms',
#        '52,800 kms', '1,95,000 kms', '48,008 kms', '48,247 kms',
#        '9,400 kms', '64,000 kms', '2,137 kms', '10,544 kms', '49,500 kms',
#        '1,47,000 kms', '90,001 kms', '48,006 kms', '74,000 kms',
#        '85,000 kms', '29,500 kms', '39,700 kms', '67,000 kms',
#        '19,336 kms', '60,105 kms', '45,933 kms', '1,02,563 kms',
#        '28,600 kms', '41,800 kms', '1,16,000 kms', '42,590 kms',
#        '7,400 kms', '54,500 kms', '76,000 kms', '00 kms', '11,523 kms',
#        '38,600 kms', '95,500 kms', '37,458 kms', '85,960 kms',
#        '12,516 kms', '30,600 kms', '2,550 kms', '62,500 kms',
#        '69,000 kms', '28,400 kms', '68,485 kms', '3,500 kms',
#        '85,455 kms', '63,000 kms', '1,600 kms', '77,000 kms',
#        '26,500 kms', '2,875 kms', '13,900 kms', '1,500 kms', '2,450 kms',
#        '1,625 kms', '33,400 kms', '60,123 kms', '38,900 kms',
#        '1,37,495 kms', '91,200 kms', '1,46,000 kms', '1,00,800 kms',
#        '2,100 kms', '2,500 kms', '1,32,000 kms', 'Petrol'], dtype=object)

# %%
data['kms_driven'].isna().sum()
# Out:
# np.int64(52)

# %% [markdown]
# ### Drop all the missing records
#   - dropping rows that have missing values

# %%
data.dropna(axis=0)
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 2      22,000 kms    Petrol
# 3      28,000 kms    Petrol
# 4      36,000 kms    Diesel
# ..            ...       ...
# 883    50,000 kms    Petrol
# 885    30,000 kms    Diesel
# 886  1,32,000 kms    Petrol
# 888    27,000 kms    Diesel
# 889    40,000 kms    Diesel
#
# [837 rows x 6 columns]

# %%
# dropping columns that have missing values
data.dropna(axis=1)
# Out:
#                                        name    company  year          Price
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
# [892 rows x 4 columns]

# %%
# drop only those records where all the values are missing
data.dropna(how='all', axis=0)
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# 1        40 kms    Diesel
# 2    22,000 kms    Petrol
# 3    28,000 kms    Petrol
# 4    36,000 kms    Diesel
# ..          ...       ...
# 887         NaN       NaN
# 888  27,000 kms    Diesel
# 889  40,000 kms    Diesel
# 890      Petrol       NaN
# 891      Petrol       NaN
#
# [892 rows x 6 columns]

# %%
data.dropna(how='any', axis=0)
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 2      22,000 kms    Petrol
# 3      28,000 kms    Petrol
# 4      36,000 kms    Diesel
# ..            ...       ...
# 883    50,000 kms    Petrol
# 885    30,000 kms    Diesel
# 886  1,32,000 kms    Petrol
# 888    27,000 kms    Diesel
# 889    40,000 kms    Diesel
#
# [837 rows x 6 columns]

# %%
int(data.shape[1]*.70)
# Out:
# 4

# %%
int(data.shape[1] *.70)
# Out:
# 4

# %%
# retain all the records where at least 70% value are valid
data.dropna(axis=0, thresh=int(data.shape[1]*.70)).isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
data.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
# retain all the records where at least 70% value are valid
data.dropna(axis=1, thresh=int(data.shape[0]*.70)).isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
# drop all those records where ALL value missing in year price or kms_driven
data.dropna(axis=0, subset=['year','Price','kms_driven'],how='all').isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %% [markdown]
# # Filling Missing Data

# %%
# fill all the missing value with ahardcoded value like 0 we did, 
data.fillna(0)
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# 1        40 kms    Diesel
# 2    22,000 kms    Petrol
# 3    28,000 kms    Petrol
# 4    36,000 kms    Diesel
# ..          ...       ...
# 887           0         0
# 888  27,000 kms    Diesel
# 889  40,000 kms    Diesel
# 890      Petrol         0
# 891      Petrol         0
#
# [892 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %% [markdown]
# # Filling missing data using mean , median , mode , min , max

# %%
sum((19,23,1,3,53))/5
# Out:
# 19.8

# %% [markdown]
# # Central Tendency
# -   if there is outlier in data we will use median
# -   if there is not outlier in data we will use mean
# -   for categorical e will use mode
#
# Bfill(), ffill()

# %%
data.fuel_type.isna().sum()
# Out:
# np.int64(55)

# %%
data.kms_driven.isna().sum()
# Out:
# np.int64(52)

# %%
data.fuel_type.value_counts()
# Out:
# fuel_type
# Petrol    440
# Diesel    395
# LPG         2
# Name: count, dtype: int64

# %%
data.fuel_type.value_counts(dropna=False)
# Out:
# fuel_type
# Petrol    440
# Diesel    395
# NaN        55
# LPG         2
# Name: count, dtype: int64

# %%
data.fuel_type.mode()
# Out:
# 0    Petrol
# Name: fuel_type, dtype: object

# %%
mode_value = data.fuel_type.mode()[0]
mode_value
# Out:
# 'Petrol'

# %%
data.fuel_type.fillna(mode_value)
# Out:
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
#         ...
# 887    Petrol
# 888    Diesel
# 889    Diesel
# 890    Petrol
# 891    Petrol
# Name: fuel_type, Length: 892, dtype: object

# %%
data.fuel_type.isnull().sum()
# Out:
# np.int64(55)

# %%
data.fuel_type = data.fuel_type.fillna(data.fuel_type.mode()[0])
data.fuel_type
# Out:
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
#         ...
# 887    Petrol
# 888    Diesel
# 889    Diesel
# 890    Petrol
# 891    Petrol
# Name: fuel_type, Length: 892, dtype: object

# %%
data.fuel_type.value_counts(dropna=False)
# Out:
# fuel_type
# Petrol    495
# Diesel    395
# LPG         2
# Name: count, dtype: int64

# %%
data.fuel_type.isna().sum()
# Out:
# np.int64(0)

# %%
data.dropna(subset=['kms_driven'], inplace=True)

# %%
data['kms_driven'] = data['kms_driven'].apply(lambda x: x.replace(' kms', '').replace(',', ''))

# %%
data.kms_driven.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 data.kms_driven.astype(float)
#
# File c:\Users\Imran BT\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File c:\Users\Imran BT\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File c:\Users\Imran BT\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\Imran BT\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File c:\Users\Imran BT\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\Imran BT\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\Imran BT\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'Petrol'

# %%
data = data.dropna(subset=['kms_driven'])

# %%
mean_value = data[data['kms_driven'] != 'Petrol']['kms_driven'].astype(float).mean()

# %%
data['kms_driven'] = data['kms_driven'].apply(lambda x: x.replace('Petrol', str(int(mean_value))))

# %%
data.kms_driven = data.kms_driven.astype(float)

# %%
data.shape
# Out:
# (840, 6)

# %%
data.isna().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
data['Price'] = data['Price'].apply(lambda x: x.replace(',', ''))

# %%
data[data['Price'] != 'Ask For Price']
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#      kms_driven fuel_type
# 0       45000.0    Petrol
# 1          40.0    Diesel
# 3       28000.0    Petrol
# 4       36000.0    Diesel
# 6       41000.0    Diesel
# ..          ...       ...
# 886    132000.0    Petrol
# 888     27000.0    Diesel
# 889     40000.0    Diesel
# 890     46010.0    Petrol
# 891     46010.0    Petrol
#
# [819 rows x 6 columns]

# %%
data = data[data['Price'] != 'Ask For Price']

# %%
data['Price'] = data['Price'].astype(float)

# %%
data['Price']
# Out:
# 0       80000.0
# 1      425000.0
# 3      325000.0
# 4      575000.0
# 6      175000.0
#          ...
# 886    300000.0
# 888    260000.0
# 889    390000.0
# 890    180000.0
# 891    160000.0
# Name: Price, Length: 819, dtype: float64

# %%
data.isna().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
data.year
# Out:
# 0      2007
# 1      2006
# 3      2014
# 4      2014
# 6      2012
#        ...
# 886    2009
# 888    2018
# 889    2013
# 890    2014
# 891    2014
# Name: year, Length: 819, dtype: object

# %%
def year_column_transformation(year):
    try:
        result = int(year)
    except:
        result = None
    return result

# %%
data['year'] = data['year'].apply(year_column_transformation)

# %%
mode = data['year'].mode()
mode
# Out:
# 0    2015
# Name: year, dtype: int64

# %%
data['year'] = data['year'].fillna(mode[0]).astype(int)

# %%
data['fuel_type'] = data['fuel_type'].fillna(data['fuel_type'].mode()[0])

# %%
data.isna().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
data.to_csv('cleaned_data.csv')

# %%
dd# it will not work, bcz we have a string value in the data that can not be 
# converted into float {petrol}
data.kms_driven.str.replace("kms", "").str.replace(",", '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 dd# it will not work, bcz we have a string value in the data that can not be
#       2 # converted into float {petrol}
#       3 data.kms_driven.str.replace("kms", "").str.replace(",", '').astype(float)
#
# NameError: name 'dd' is not defined

# %%
[data.kms_driven == 'Petrol']
# Out:
# [0      False
#  1      False
#  3      False
#  4      False
#  6      False
#         ...
#  886    False
#  888    False
#  889    False
#  890    False
#  891    False
#  Name: kms_driven, Length: 819, dtype: bool]

# %%
data.kms_driven.replace('Petrol', '0', inplace=True)

# %%
data['kms_driven']
# Out:
# 0       45000.0
# 1          40.0
# 3       28000.0
# 4       36000.0
# 6       41000.0
#          ...
# 886    132000.0
# 888     27000.0
# 889     40000.0
# 890     46010.0
# 891     46010.0
# Name: kms_driven, Length: 819, dtype: float64

# %%
data.kms_driven.replace('Petrol', '0', inplace=True)

# %%
data.kms_driven.replace('NaN', '0', inplace=True)

# %%
# petrol is treplaced by 0 and kms can be converted into f
data.kms_driven = data.kms_driven.replace("kms","").replace(",",'').astype(float)

# %%
data.kms_driven.isna().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(data.kms_driven)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 sns.boxplot(data.kms_driven)
#
# NameError: name 'sns' is not defined
