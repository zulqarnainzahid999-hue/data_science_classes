# %%
# Alias (short name)
import math as m 
print(m.sqrt(100))
# Out:
# 10.0

# %%
import math_utils
print(math_utils.add(4, 4))
print(math_utils.square(5))
# Out:
# 8
# None
# 25
# None

# %%
# Full import
import math
print(math.sqrt(15))
# Out:
# 3.872983346207417

# %%
# Specific cheez import
from math import sqrt
print(sqrt(25))
# Out:
# 5.0

# %%
# Built-in modules
import random
print(random.randint(1, 10))
# Out:
# 9

# %% [markdown]
# - External modules (install karne padte hain)
# - numpy
# - pandas
# - requests

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
my_tuple = (1, 2, 3)

# %%
a, b, c = my_tuple

# %%
my_tuple
# Out:
# (1, 2, 3)

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3
