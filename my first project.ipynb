# %%
# !pip install FastApi
# Out:
# Collecting FastApi
#   Downloading fastapi-0.124.2-py3-none-any.whl.metadata (30 kB)
# Collecting starlette<0.51.0,>=0.40.0 (from FastApi)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from FastApi)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting typing-extensions>=4.8.0 (from FastApi)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting annotated-doc>=0.0.2 (from FastApi)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->FastApi)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->FastApi)
#   Downloading pydantic_core-2.41.5-cp314-cp314-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->FastApi)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting anyio<5,>=3.6.2 (from starlette<0.51.0,>=0.40.0->FastApi)
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->FastApi)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Downloading fastapi-0.124.2-py3-none-any.whl (112 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp314-cp314-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 426.0 kB/s eta 0:00:04
#    ---------- ----------------------------- 0.5/2.0 MB 426.0 kB/s eta 0:00:04
#    --------------- ------------------------ 0.8/2.0 MB 546.5 kB/s eta 0:00:03
#    --------------- ------------------------ 0.8/2.0 MB 546.5 kB/s eta 0:00:03
#    -------------------- ------------------- 1.0/2.0 MB 512.4 kB/s eta 0:00:02
#    -------------------- ------------------- 1.0/2.0 MB 512.4 kB/s eta 0:00:02
#    -------------------- ------------------- 1.0/2.0 MB 512.4 kB/s eta 0:00:02
#    -------------------------- ------------- 1.3/2.0 MB 487.3 kB/s eta 0:00:02
#    -------------------------- ------------- 1.3/2.0 MB 487.3 kB/s eta 0:00:02
#    -------------------------- ------------- 1.3/2.0 MB 487.3 kB/s eta 0:00:02
#    ------------------------------- -------- 1.6/2.0 MB 498.1 kB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 540.3 kB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 548.2 kB/s  0:00:03
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-extensions, idna, annotated-types, annotated-doc, typing-inspection, pydantic-core, anyio, starlette, pydantic, FastApi
#
#    ---- -----------------------------------  1/10 [idna]
#    ---- -----------------------------------  1/10 [idna]
#    ---- -----------------------------------  1/10 [idna]
#    ---------------- -----------------------  4/10 [typing-inspection]
#    -------------------- -------------------  5/10 [pydantic-core]
#    ------------------------ ---------------  6/10 [anyio]
#    ------------------------ ---------------  6/10 [anyio]
#    ------------------------ ---------------  6/10 [anyio]
#    ------------------------ ---------------  6/10 [anyio]
#    ------------------------ ---------------  6/10 [anyio]
#    ------------------------ ---------------  6/10 [anyio]
#    ------------------------ ---------------  6/10 [anyio]
#    ------------------------ ---------------  6/10 [anyio]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    ------------------------------------ ---  9/10 [FastApi]
#    ------------------------------------ ---  9/10 [FastApi]
#    ------------------------------------ ---  9/10 [FastApi]
#    ------------------------------------ ---  9/10 [FastApi]
#    ------------------------------------ ---  9/10 [FastApi]
#    ------------------------------------ ---  9/10 [FastApi]
#    ------------------------------------ ---  9/10 [FastApi]
#    ------------------------------------ ---  9/10 [FastApi]
#    ------------------------------------ ---  9/10 [FastApi]
#    ------------------------------------ ---  9/10 [FastApi]
#    ---------------------------------------- 10/10 [FastApi]
#
# Successfully installed FastApi-0.124.2 annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.12.0 idna-3.11 pydantic-2.12.5 pydantic-core-2.41.5 starlette-0.50.0 typing-extensions-4.15.0 typing-inspection-0.4.2

# %%
pip install fastapi uvicorn
# Out:
# Requirement already satisfied: fastapi in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (0.124.2)
# Collecting uvicorn
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from fastapi) (0.50.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from fastapi) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi) (4.12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (3.11)
# Collecting click>=7.0 (from uvicorn)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting h11>=0.8 (from uvicorn)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: colorama in c:\users\imran bt\appdata\roaming\python\python314\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: h11, click, uvicorn
#
#    ---------------------------------------- 0/3 [h11]
#    ---------------------------------------- 0/3 [h11]
#    ---------------------------------------- 0/3 [h11]
#    ---------------------------------------- 0/3 [h11]
#    ---------------------------------------- 0/3 [h11]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    -------------------------- ------------- 2/3 [uvicorn]
#    -------------------------- ------------- 2/3 [uvicorn]
#    -------------------------- ------------- 2/3 [uvicorn]
#    -------------------------- ------------- 2/3 [uvicorn]
#    -------------------------- ------------- 2/3 [uvicorn]
#    -------------------------- ------------- 2/3 [uvicorn]
#    -------------------------- ------------- 2/3 [uvicorn]
#    -------------------------- ------------- 2/3 [uvicorn]
#    -------------------------- ------------- 2/3 [uvicorn]
#    -------------------------- ------------- 2/3 [uvicorn]
#    ---------------------------------------- 3/3 [uvicorn]
#
# Successfully installed click-8.3.1 h11-0.16.0 uvicorn-0.38.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastapi import FastAPI, Depends, UploadFile, File, Form, HTTPException

# %%
fastapi
uvicorn[standard]
sqlalchemy
databases[sqlite]
pydantic
python-jose[cryptography]
passlib[bcrypt]
python-multipart
aiofiles
sentence-transformers
faiss-cpu
redis
requests
typing_extensions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 fastapi
#       2 uvicorn[standard]
#       3 sqlalchemy
#
# NameError: name 'fastapi' is not defined

# %%
# !pip install uvicorn
# Out:
# Requirement already satisfied: uvicorn in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (0.38.0)
# Requirement already satisfied: click>=7.0 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\imran bt\appdata\local\programs\python\python314\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\imran bt\appdata\roaming\python\python314\site-packages (from click>=7.0->uvicorn) (0.4.6)

# %%
# --- IMPORTS ---
from fastapi import FastAPI
from pydantic import BaseModel

# --- APP INIT ---
app = FastAPI()

# --- MODEL / REQUEST BODY ---
class Item(BaseModel):
    name: str
    price: int
    description: str | None = None

# --- ROUTES ---

@app.get("/")
def home():
    return {"message": "FastAPI is working perfectly!"}

@app.get("/hello/{name}")
def say_hello(name: str):
    return {"message": f"Hello {name}"}

@app.post("/add-item")
def add_item(item: Item):
    return {
        "received_item": item,
        "note": "Data received successfully!"
    }

# %%
uvicorn main:app --reload
# Out:
#   Cell In[18], line 1
#     uvicorn main:app --reload
#             ^
# SyntaxError: invalid syntax

# %%
uvicorn --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 uvicorn --version
#
# NameError: name 'uvicorn' is not defined

# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/")
def home():
    return {"message": "AI working perfectly!"}

# %%
fastapi
uvicorn[standard]
sqlalchemy
databases[sqlite]
pydantic
python-jose[cryptography]
passlib[bcrypt]
python-multipart
aiofiles
sentence-transformers
faiss-cpu
redis
requests
typing_extensions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 fastapi
#       2 uvicorn[standard]
#       3 sqlalchemy
#
# NameError: name 'fastapi' is not defined
